# %% [markdown]
# # Project Demo Notebook
#
# This notebook should run top-to-bottom and generate your results.
#
# Start with a small input, then scale up.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal
import soundfile as sf

# Optional: live playback (may fail on some systems)
try:
    import sounddevice as sd
except Exception:
    sd = None

# %%
# TODO: Load/generate input signal
sr = 48000
t = np.arange(int(sr*2.0))/sr
x = np.sin(2*np.pi*220*t)

# %%
# TODO: Apply your DSP block(s)
y = x.copy()

# %%
# Visualize
plt.figure()
plt.plot(x[:2000], label="x")
plt.plot(y[:2000], label="y", alpha=0.7)
plt.legend()
plt.title("Time domain (first 2000 samples)")
plt.show()
