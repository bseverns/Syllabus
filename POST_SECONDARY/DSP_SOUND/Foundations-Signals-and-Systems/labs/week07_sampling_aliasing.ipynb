# %% [markdown]
# # Week 07 — Sampling + quantization: aliasing as a design constraint
#
# This notebook is intentionally scaffolded but incomplete.
#
# Fill in the TODOs during class.
#
# **Suggested loop**
# 1) listen/inspect → 2) plot → 3) modify → 4) explain

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal
import soundfile as sf

# Optional: live playback (may fail on some systems)
try:
    import sounddevice as sd
except Exception:
    sd = None

# %%
# TODO: Load or generate a signal you care about
sr = 48000
t = np.arange(int(sr*1.0))/sr
x = np.sin(2*np.pi*440*t)

# %%
# TODO: Do the week’s main operation
# - Week 05: Fourier series reconstruction
# - Week 06: FFT + windowing comparisons
# - Week 07: sampling/quantization experiments
# - Week 08: FIR design + frequency response
# - Week 09: IIR design + stability checks
# - Week 10: spectrogram + feature extraction
# - Week 11: noise + denoise experiments

# %%
# TODO: Make at least one plot that proves what you’re claiming
plt.figure()
plt.plot(x[:1000])
plt.title("Replace this plot with something meaningful")
plt.show()
