# %% [markdown]
# # Week 12 — Final project work session
#
# Use this notebook as a scratchpad or as your demo notebook.
#
# If you’re building your own `project/demo.ipynb`, keep this one minimal.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal
import soundfile as sf

# Optional: live playback (may fail on some systems)
try:
    import sounddevice as sd
except Exception:
    sd = None

# %%
# TODO: Work on your project demo here, or move everything into `project/demo.ipynb`.
print("Make something you can explain.")
