# %% [markdown]
# # Week 11 — Midi Basics
#
# Scaffold notebook. Fill in during class with plots + notes.
#
# Load CSV logs from `export/` and make one plot that proves your claim.

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

# %%
# TODO: load a CSV from export/
from pathlib import Path
p = Path("..")/"export"/"week11.csv"
print("Loading:", p)

# %%
# TODO: parse the lines for your week’s format
# Common patterns:
# - value only
# - t_ms,value
# - t_ms,raw,processed

# %%
# TODO: plot something meaningful
# plt.figure(); plt.plot(...); plt.show()
