# %% [markdown]
# # Week 08 — Lab notebook
#
# Scaffold: fill with measurements, plots, and notes.

# %%
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

# %%
print('TODO: add your experiment and evidence for this week')
